# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents

# %%
# Run this code:

salaries = pd.read_csv('../Current_Employee_Names__Salaries__and_Position_Titles.csv')

salaries
# Out:
#                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4          ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
# ...                      ...                                     ...
# 33178  ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 33179     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33180      ZYMANTAS,  MARK E                          POLICE OFFICER
# 33181    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 33182   ZYSKOWSKI,  DARIUSZ                  CHIEF DATA BASE ANALYST
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:
salaries.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
salaries["Hourly Rate"].isnull().value_counts()
# Out:
# True     25161
# False     8022
# Name: Hourly Rate, dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
# Salary or Hourly


salaries["Salary or Hourly"].value_counts()
# Out:
# Salary    25161
# Hourly     8022
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
salaries.groupby(by="Department").count()
#ok but lets say I want to only get Department and Name
# Out:
#                         Name  Job Titles  Full or Part-Time  Salary or Hourly  \
# Department
# ADMIN HEARNG              39          39                 39                39
# ANIMAL CONTRL             81          81                 81                81
# AVIATION                1629        1629               1629              1629
# BOARD OF ELECTION        107         107                107               107
# BOARD OF ETHICS            8           8                  8                 8
# BUDGET & MGMT             46          46                 46                46
# BUILDINGS                269         269                269               269
# BUSINESS AFFAIRS         171         171                171               171
# CITY CLERK                84          84                 84                84
# CITY COUNCIL             411         411                411               411
# COMMUNITY DEVELOPMENT    207         207                207               207
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:
 #we will test whether the hourly wage of all hourly workers is significantly different from $30/hr
from collections import Counter
from scipy.stats import binom_test
from scipy.stats import ttest_ind 
from scipy.stats import ttest_1samp

#el que hay que cojer es hourly rate
#utilizar nonnull()  para fuiltrar por notnull

#is the hourly wage significant different from 30?


"""#remainers = remain_leave[remain_leave['brexit'] == 1]
hourly_workers = hourly_workers[["Hourly Rate"]]
hourly_workers 
media = 30
population = hourly_workers.mean()
#hourly_workers[hourly_workers.notnull()]

#np.random.shuffle(population)

#hipotesis: the hourly wage of all hourly workers is significantly different from $30/hr
#pistas juan: 
# Dentro de la libreria de scipy importamos stats
#dentro de stats si google haccemos ttest_ind
# ttest_1samp
#aquí tenemos que conseguir ese hourly range quitando lo nulos
# calcula el test para la media de 1 grupo
# parametros: la estructura básica es 

#Parametros: 
#salaries
#hourly rate
"""

media=30


ttest_1samp(salaries[salaries['Hourly Rate'].notnull()]["Hourly Rate"], 30)

#(statistic=20.6198057854942, pvalue=4.3230240486229894e-92)
#esto significa que la probabilidad de que sea 30 es 0.4
#intervalo de confianza de 5

#Hipotesis nula = 0 es decir que en este caso si tiene un valor de 30 SIEMPRE ES AFIRMATIVA
#hipotesis alternativa = tiene valor 30 SIEMPRE ES NEGATIVA: MI HIPOTESIS ALTERNATIVA ES QUE NO TIENE 30

#scipy.stats.ttest_1samp(salaries[salaries['Hourly Rate'].notnull()]["Hourly Rate"], media, axis=0, nan_policy='propagate', alternative='two-sided')
#groupby dataframe
# Out:
# Ttest_1sampResult(statistic=20.6198057854942, pvalue=4.3230240486229894e-92)

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
# Your code here:
salarie_mean = salaries[["Annual Salary"]].mean()
population = salaries[salaries["Annual Salary"].notnull()].copy()
population = population["Annual Salary"]
population

#hipothesisnula = 0
#p-value = 0
#experiment = np.random.choice(['heads', 'tails'], 250)


#Shuffle the population
# Out:
# 0        101442.0
# 1         94122.0
# 2        101592.0
# 3        110064.0
# 5         50436.0
#            ...
# 33178     72510.0
# 33179     48078.0
# 33180     90024.0
# 33181     93354.0
# 33182    115932.0
# Name: Annual Salary, Length: 25161, dtype: float64

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:

#Hourly Rate 
#Department
pd.crosstab(salaries["Department"], salaries["Hourly Rate"], margins=True, margins_name="Total").sort_values('Total', ascending=False)
# Out:
# Hourly Rate            2.65  8.25  9.27  9.46  9.5  10.0  10.5  11.0  12.0  \
# Department
# Total                   206    25     4     6    1     5     2     2    22
# STREETS & SAN             0     0     0     0    0     0     0     0     0
# WATER MGMNT               0     0     0     0    0     0     0     0     0
# OEMC                      0     0     0     0    0     0     0     0     0
# AVIATION                  0     0     0     0    0     0     0     0     0
# GENERAL SERVICES          0     0     0     0    0     0     0     0     0
# TRANSPORTN                0     0     0     0    0     0     0     0     0
# PUBLIC LIBRARY            0     0     0     0    0     0     0     0     0
# FAMILY & SUPPORT        206    25     0     0    0     0     0     0     0
# CITY COUNCIL              0     0     0     0    1     1     2     0    15
# FINANCE                   0     0     0     0    0     0     0     0     0
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:

#STREETS & SAN

#hourly wage is less than $35/hour

#test this one-sided hypothesis at the 95% confidence level.

from scipy.stats import ttest_ind 
from scipy.stats import ttest_1samp



STREETS_hours = salaries.loc[salaries["Department"]=="STREETS & SAN"][["Hourly Rate"]].dropna()
mean = 35
STREETS_hours
STREETS_hours.mean()
#_, p_value = ttest_ind(STREETS_hours, mean, equal_var=True)
#print(f'The probability that the hourly wage is less than $35/hour {p_value}:')


#https://www.statisticssolutions.com/conduct-interpret-one-sample-t-test/#:~:text=The%20one%2Dsample%20t%2Dtest%20compares%20the%20mean%20of%20a,the%20mean%20of%20another%20group

tscore, pvalue = ttest_1samp(STREETS_hours, popmean=33)
print("t Statistic: ", tscore)  
print("P Value: ", pvalue)

#no entiendo
# Out:
# t Statistic:  [5.48018191]
# P Value:  [4.82799777e-08]

# %% [markdown]
# # Challenge 3 - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:
from scipy.stats import t

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
# Your code here:

# %% [markdown]
# # Challenge 4 - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

import pandas as pd
np.random.seed(123)

# Let us welcome SciPy!
from scipy.stats import trim_mean, mode, skew, gaussian_kde, pearsonr, spearmanr, beta

# %%
population_mean = 23646.50
population_std = 5000
population = 10000

mock_salaries = np.random.normal(population_mean, population_std, population)
mock_salaries
# Out:
# array([18218.3469835 , 28633.22723292, 25061.39249026, ...,
#        21285.16793447, 26556.32182634, 28499.56431377])

# %%
plt.hist(mock_salaries, bins=20, density=True)
plt.axvline(np.mean(mock_salaries), c="red")
plt.title('Histogram of mock Salaries in Spain', size=20)
plt.xlabel('Euros')
plt.ylabel('frequency')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#Me dan estos datos, 
#cojo una muestra

sample_size = 15
sample = np.random.normal(population_mean, population_std, sample_size)
sample

print(f'Sample mean: {np.round(np.mean(sample))}, ', 
      f'Sample std: {np.round(np.std(sample))}')
# Out:
# Sample mean: 22876.0,  Sample std: 4766.0

# %%
#
#La prueba t de una muestra compara la media de una sola muestra con un valor predeterminado
#para determinar si la media de la muestra es significativamente mayor o menor que ese valor.

# %%
#list_of_samples = [np.mean(np.random.normal(population_mean, population_std, sample_size)) for _ in range(1000)]

sample = np.random.normal(population_mean, population_std, sample_size) 

listofmeans= [np.mean(np.random.normal(population_mean, population_std, sample_size)) for _ in range(1000)]


#sample.max()
#sample.min()

sample.mean()

#listofmeans
# Out:
# 23046.538698577737
